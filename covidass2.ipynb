# %%
import pandas as pd

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_excel('Covid.xlsx')

# %%
data.to_csv('covid.csv', index=False)

# %%
tn, fp, fn, tp = 395, 55, 5, 45

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assume a pre-defined confusion matrix based on provided values
# True Negatives (TN), False Positives (FP), False Negatives (FN), True Positives (TP)
tn, fp, fn, tp = 395, 55, 5, 45

# Manually construct the confusion matrix
conf_matrix = [[tn, fp], [fn, tp]]

# Calculate metrics
# Accuracy: (TP + TN) / (TP + TN + FP + FN)
accuracy = (tp + tn) / (tp + tn + fp + fn)

# Precision: TP / (TP + FP)
precision = tp / (tp + fp)

# Recall: TP / (TP + FN)
recall = tp / (tp + fn)

# F1 Score: 2 * (Precision * Recall) / (Precision + Recall)
f1 = (2 * precision * recall) / (precision + recall)

# Print results with step-by-step calculations
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nMetrics Calculations:")
print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"True Negatives (TN): {tn}")
print(f"False Negatives (FN): {fn}")

print(f"\nAccuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[395, 55], [5, 45]]
#
# Metrics Calculations:
# True Positives (TP): 45
# False Positives (FP): 55
# True Negatives (TN): 395
# False Negatives (FN): 5
#
# Accuracy: 0.88
# Precision: 0.45
# Recall: 0.90
# F1 Score: 0.60

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file (assuming you've already converted the Excel file to CSV)
data = pd.read_csv('covid.csv')  # Replace 'covid.csv' with the actual CSV file path

# Calculate the confusion matrix
conf_matrix = confusion_matrix(data['Actual'], data['Predicted'])

# Extract TN, FP, FN, TP from the confusion matrix
tn, fp, fn, tp = conf_matrix.ravel()

# Calculate metrics
accuracy = (tp + tn) / (tp + tn + fp + fn)
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# Print results with step-by-step calculations
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nMetrics Calculations:")
print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"True Negatives (TN): {tn}")
print(f"False Negatives (FN): {fn}")

print(f"\nAccuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[395   5]
#  [ 55  45]]
#
# Metrics Calculations:
# True Positives (TP): 45
# False Positives (FP): 5
# True Negatives (TN): 395
# False Negatives (FN): 55
#
# Accuracy: 0.88
# Precision: 0.90
# Recall: 0.45
# F1 Score: 0.60
